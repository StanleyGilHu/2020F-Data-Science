# %%
import csv 
import itertools

filename = "heartFailure.csv"
   
colNum = 0
scans = 1
min_sup = 60
lengh = 0
fields = []
rows = []
items = []
finalMatches = dict()

def aprioriStart(items):
    itemL = dict()
    itemL["age"] = 0
    itemL["ane"] = 0
    itemL["cre"] = 0
    itemL["dia"] = 0
    itemL["eje"] = 0
    itemL["hig"] = 0
    itemL["pla"] = 0
    itemL["seC"] = 0
    itemL["seS"] = 0
    itemL["mal"] = 0 #
    itemL["fem"] = 0 #
    itemL["smo"] = 0
    itemL["tme"] = 0
    itemL["dth"] = 0

    for item in items:
        if int(item) == 1:
            itemL["age"] += 1
        elif int(item) == 2:
            itemL["ane"] += 1
        elif int(item) == 3:
            itemL["cre"] += 1
        elif int(item) == 4:
            itemL["dia"] += 1
        elif int(item) == 5:
            itemL["eje"] += 1
        elif int(item) == 6:
            itemL["hig"] += 1
        elif int(item) == 7:
            itemL["pla"] += 1
        elif int(item) == 8:
            itemL["seC"] += 1
        elif int(item) == 9:
            itemL["seS"] += 1
        elif int(item) == 10:
            itemL["mal"] += 1#
        elif int(item) == 14:#
            itemL["fem"] += 1#
        elif int(item) == 11:
            itemL["smo"] += 1
        elif int(item) == 12:
            itemL["tme"] += 1
        elif int(item) == 13:
            itemL["dth"] += 1
    
    for item in itemL:
        if itemL[item] > min_sup:
            finalMatches[item] = itemL[item]
    print("age: %s" %itemL["age"])
    print("anaemia: %s" %itemL["ane"])
    print("creatinine phosphokinase: %s" %itemL["cre"])
    print("diabetes: %s" %itemL["dia"])
    print("ejection fraction: %s" %itemL["eje"])
    print("high blood pressure: %s" %itemL["hig"])
    print("platelets: %s" %itemL["pla"])
    print("serum creatinine: %s" %itemL["seC"])
    print("serum sodium: %s" %itemL["seS"])
    print("male: %s" %itemL["mal"]) #
    print("female: %s" %itemL["fem"]) #
    print("smoking: %s" %itemL["smo"])
    #print("Time: %s" %item["tme"])
    print("Deaths: %s" %itemL["dth"])
    apriori(itemL)

def apriori(itemL):
    i = 0
    itemN = dict()
    for item1 in list(itemL):
        i += 1
        match = 0
        rest = dict(itertools.islice(itemL.items(), i, len(itemL)))
        for item2 in rest:
            if itemL[item1] >= min_sup and (itemL[item2] >= min_sup or item2 == "death"):
                print("Items: %s %s" %(item1, item2))
                newMatch = "%s, %s" %(item1, item2)
                itemN[newMatch] = 0
                match += 1
        if match == 0:
            itemL.pop(item1)
            i -= 1
    print("Creating matches:")
    print(itemN)
    aprioriCon(itemN)

def apriori2(itemL):
    i = 0
    itemN = dict()
    for item1 in list(itemL):
        pair1 = item1.split(", ")
        i += 1
        match = 0
        rest = dict(itertools.islice(itemL.items(), i, len(itemL)))
        for item2 in rest:
            newMatch = ""
            pair2 = item2.split(", ")
            connection = 0
            for pairItem in pair1:
                k = 0
                if pairItem != pair2[0]:
                    continue
                for pairItem2 in pair2:
                    if pairItem == pairItem2:
                        pair2.pop(k)
                        connection += 1 
                    k += 1
            if connection < 1:
                continue
            if itemL[item1] >= min_sup and itemL[item2] >= min_sup and connection == (len(pair1)-1) and len(pair2) > 0:
                for itms in pair1:
                    newMatch += itms + ", "
                for itms in pair2:
                    newMatch += itms + ", "
                cut = len(newMatch)
                newMatch = newMatch[:cut - 2]
                itemN[newMatch] = 0
                match += 1
    print("Creating matches:")
    print(itemN)
    print('\n')
    if len(itemN) > 0:
        aprioriCon(itemN)
    else:
        print("All Matches:")
        print(finalMatches)
        print("Confidence that given other variables, death will occur:")
        for item in finalMatches:
            pair = item.split(", ")
            if pair[(len(pair)-1)] == "dth" and len(pair) > 1:
                pair.pop(len(pair)-1)
                coef = ""
                for itms in pair:
                    coef += itms + ", "
                cut = len(coef)
                coef = coef[:cut - 2]
                confidence = finalMatches[item]/finalMatches[coef]
                print("Given %s, probabilty of death is: %s" %(coef, confidence))

def aprioriCon(itemN):
    itemP = dict()
    itemL = dict()
    itemL["age"] = 0
    itemL["ane"] = 0
    itemL["cre"] = 0
    itemL["dia"] = 0
    itemL["eje"] = 0
    itemL["hig"] = 0
    itemL["pla"] = 0
    itemL["seC"] = 0
    itemL["seS"] = 0
    itemL["mal"] = 0 #
    itemL["fem"] = 0 #
    itemL["smo"] = 0
    itemL["tme"] = 0
    itemL["dth"] = 0
    for pairItem in itemN:
        pair = pairItem.split(", ")
        #print(pair)
        #print('\n')
        matches = 0
        alreadyM = 0
        for item in items:
            if item == -1:
                itemL["age"] = 0
                itemL["ane"] = 0
                itemL["cre"] = 0
                itemL["dia"] = 0
                itemL["eje"] = 0
                itemL["hig"] = 0
                itemL["pla"] = 0
                itemL["seC"] = 0
                itemL["seS"] = 0
                itemL["mal"] = 0 #
                itemL["fem"] = 0 #
                itemL["smo"] = 0
                itemL["tme"] = 0
                itemL["dth"] = 0
                alreadyM = 0
            elif int(item) == 1:
                itemL["age"] = 1
            elif int(item) == 2:
                itemL["ane"] = 1
            elif int(item) == 3:
                itemL["cre"] = 1
            elif int(item) == 4:
                itemL["dia"] = 1
            elif int(item) == 5:
                itemL["eje"] = 1
            elif int(item) == 6:
                itemL["hig"] = 1
            elif int(item) == 7:
                itemL["pla"] = 1
            elif int(item) == 8:
                itemL["seC"] = 1
            elif int(item) == 9:
                itemL["seS"] = 1
            elif int(item) == 10:
                itemL["mal"] = 1
            elif int(item) == 11:
                itemL["smo"] = 1
            elif int(item) == 12:
                itemL["tme"] = 1
            elif int(item) == 13:
                itemL["dth"] = 1
            elif int(item) == 14:
                itemL["fem"] = 1
            match = len(pair)
            for pairI in pair:
                #print(pairI)
                if itemL[pairI] == 1:
                    match -= 1
            if match == 0 and alreadyM == 0:
                alreadyM = 1
                matches += 1
        if matches >= min_sup:
            itemP[pairItem] = matches
            finalMatches[pairItem] = itemP[pairItem]
    print("checking total matches:")
    print(itemP)
    print('\n')
    apriori2(itemP)



with open(filename, 'r') as csvfile:  
    csvreader = csv.reader(csvfile) 

    fields = next(csvreader) 
 
    for row in csvreader: 
        rows.append(row)  
print("Enter Min_Sup")
min_sup = int(input())
#------------------------------------CHANGE STUFF HERE FOR OUTLIERS---------------------------------------------
for row in rows:  
    colNum = 0
    for col in row:	
        colNum += 1
        if colNum == 1:
            if float(col) >= 65:
                print("age: %s" %col)
                items.append(1)
        elif colNum == 2:
            if int(col) == 1:
                print("anaemia: %s" %col)
                items.append(2)
        elif colNum == 3:
            if float(col) >= 450:
                print("creatinine phosphokinase: %s" %col)
                items.append(3)
        elif colNum == 4:
            if int(col) == 1:
                print("diabetes: %s" %col)
                items.append(4)
        elif colNum == 5:
            if float(col) > 90 or float(col) < 33:
                print("ejection fraction: %s" %col)
                items.append(5)
        elif colNum == 6:
            if int(col) == 1:
                print("high blood pressure: %s" %col)
                items.append(6)
        elif colNum == 7:
            if float(col) > 600000 or float(col) < 100000:
                print("platelets: %s" %col)
                items.append(7)
        elif colNum == 8:
            if float(col) > 1.71 or float(col) < .44:
                print("serum creatinine: %s" %col)
                items.append(8)
        elif colNum == 9:
            if float(col) > 160 or float(col) < 120:
                print("serum sodium: %s" %col)
                items.append(9)
        elif colNum == 10:
            if int(col) == 1:
                print("sex: %s" %col)
                items.append(10)
            else:
                items.append(14)
        elif colNum == 11:
            if int(col) == 1:
                print("smoking: %s" %col)
                items.append(11)
        #elif colNum == 12:
            #if int(col) >= 60:
                #print("time: %s" %col)
                #items.append(12)
        elif colNum == 13:
            if int(col) == 1:
                print("DEATH EVENT: %s" %col)
                items.append(13)
            #print("column: %g" %colNum)
        #print(col),
    items.append(-1)
    print('\n') 
aprioriStart(items)
# Out:
# Enter Min_Sup
# 25
# age: 75
# creatinine phosphokinase: 582
# ejection fraction: 20
# high blood pressure: 1
# serum creatinine: 1.9
# sex: 1
# DEATH EVENT: 1
#
#
# creatinine phosphokinase: 7861
# sex: 1
# DEATH EVENT: 1
#
#
# age: 65
# ejection fraction: 20
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# ejection fraction: 20
# serum creatinine: 1.9
# sex: 1
# DEATH EVENT: 1
#
#
# age: 65
# anaemia: 1
# diabetes: 1
# ejection fraction: 20
# serum creatinine: 2.7
# serum sodium: 116
# DEATH EVENT: 1
#
#
# age: 90
# anaemia: 1
# high blood pressure: 1
# serum creatinine: 2.1
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# age: 75
# anaemia: 1
# ejection fraction: 15
# sex: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# diabetes: 1
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# age: 65
# DEATH EVENT: 1
#
#
# age: 80
# anaemia: 1
# high blood pressure: 1
# serum creatinine: 9.4
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# age: 75
# anaemia: 1
# high blood pressure: 1
# serum creatinine: 4
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# ejection fraction: 25
# high blood pressure: 1
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 981
# ejection fraction: 30
# sex: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# high blood pressure: 1
# sex: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# ejection fraction: 30
# high blood pressure: 1
#
#
# age: 82
# anaemia: 1
# platelets: 47000
# sex: 1
# DEATH EVENT: 1
#
#
# age: 87
# anaemia: 1
# sex: 1
# DEATH EVENT: 1
#
#
# creatinine phosphokinase: 582
# ejection fraction: 14
# sex: 1
# DEATH EVENT: 1
#
#
# age: 70
# anaemia: 1
# ejection fraction: 25
# high blood pressure: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 582
# diabetes: 1
# platelets: 87000
# serum creatinine: 1.9
# DEATH EVENT: 1
#
#
# age: 65
# anaemia: 1
# ejection fraction: 25
# high blood pressure: 1
#
#
# age: 65
# anaemia: 1
# diabetes: 1
# ejection fraction: 30
# high blood pressure: 1
# DEATH EVENT: 1
#
#
# age: 68
# anaemia: 1
# high blood pressure: 1
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# diabetes: 1
# sex: 1
#
#
# age: 75
# creatinine phosphokinase: 582
# diabetes: 1
# ejection fraction: 30
# high blood pressure: 1
# serum creatinine: 1.83
# DEATH EVENT: 1
#
#
# age: 80
# diabetes: 1
# serum creatinine: 1.9
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# age: 95
# anaemia: 1
# high blood pressure: 1
# DEATH EVENT: 1
#
#
# age: 70
# diabetes: 1
# high blood pressure: 1
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# serum creatinine: 5.8
# sex: 1
# DEATH EVENT: 1
#
#
# age: 82
# diabetes: 1
# ejection fraction: 30
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# age:
# high blood pressure: 1
# sex: 1
# smoking: 1
#
#
# age: 78
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# diabetes: 1
# ejection fraction: 30
# high blood pressure: 1
# DEATH EVENT: 1
#
#
# age: 65
# anaemia: 1
# high blood pressure: 1
# sex: 1
#
#
# age: 73
# creatinine phosphokinase: 582
# high blood pressure: 1
# sex: 1
#
#
# age: 70
# creatinine phosphokinase: 1202
# high blood pressure: 1
#
#
# anaemia: 1
# high blood pressure: 1
# serum creatinine: 9
# DEATH EVENT: 1
#
#
# age: 68
# anaemia: 1
# creatinine phosphokinase: 1021
# diabetes: 1
# sex: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# high blood pressure: 1
#
#
# age: 73
# creatinine phosphokinase: 582
# ejection fraction: 20
# serum creatinine: 1.83
# sex: 1
# DEATH EVENT: 1
#
#
# age: 65
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# sex: 1
# smoking: 1
#
#
# creatinine phosphokinase: 582
# ejection fraction: 25
# sex: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# ejection fraction: 25
# sex: 1
#
#
# age: 75
# creatinine phosphokinase: 675
# diabetes: 1
#
#
# anaemia: 1
# ejection fraction: 25
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 2794
# high blood pressure: 1
# sex: 1
#
#
# age: 65
# ejection fraction: 25
# serum creatinine: 5
#
#
# age: 72
# ejection fraction: 25
#
#
# ejection fraction: 30
# platelets: 62000
# DEATH EVENT: 1
#
#
# age: 70
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# sex: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 707
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 582
# sex: 1
# smoking: 1
#
#
# age: 77
# anaemia: 1
# high blood pressure: 1
# sex: 1
#
#
# age: 75
# high blood pressure: 1
# sex: 1
#
#
# age: 70
# ejection fraction: 30
# sex: 1
#
#
# age: 65
# anaemia: 1
# creatinine phosphokinase: 720
# diabetes: 1
#
#
# anaemia: 1
# sex: 1
# smoking: 1
#
#
# age: 70
# diabetes: 1
# high blood pressure: 1
#
#
# age: 65
# creatinine phosphokinase: 582
# diabetes: 1
# ejection fraction: 30
# sex: 1
# smoking: 1
#
#
# sex: 1
# smoking: 1
#
#
# age: 73
# anaemia: 1
# creatinine phosphokinase: 1185
# high blood pressure: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# serum creatinine: 1.8
# sex: 1
#
#
# anaemia: 1
# diabetes: 1
# sex: 1
#
#
# creatinine phosphokinase: 2017
# ejection fraction: 25
# sex: 1
# DEATH EVENT: 1
#
#
# ejection fraction: 25
# serum creatinine: 2.4
# sex: 1
#
#
# creatinine phosphokinase: 624
# sex: 1
# smoking: 1
#
#
# diabetes: 1
#
#
# creatinine phosphokinase: 2522
# ejection fraction: 30
# high blood pressure: 1
#
#
# creatinine phosphokinase: 572
# diabetes: 1
#
#
# high blood pressure: 1
# sex: 1
#
#
# age: 70
# diabetes: 1
# high blood pressure: 1
#
#
# anaemia: 1
# high blood pressure: 1
# sex: 1
#
#
# anaemia: 1
# diabetes: 1
# ejection fraction: 30
# high blood pressure: 1
# sex: 1
# smoking: 1
#
#
# age: 65
#
#
# diabetes: 1
# high blood pressure: 1
# sex: 1
#
#
# anaemia: 1
# diabetes: 1
# ejection fraction: 25
# sex: 1
#
#
# sex: 1
# smoking: 1
#
#
# sex: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 655
#
#
# age: 65
# anaemia: 1
# diabetes: 1
# ejection fraction: 25
# sex: 1
# DEATH EVENT: 1
#
#
# age: 68
# anaemia: 1
# diabetes: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# sex: 1
#
#
# anaemia: 1
# sex: 1
# smoking: 1
#
#
# creatinine phosphokinase: 1199
# ejection fraction: 20
# serum creatinine: 1.83
# sex: 1
# smoking: 1
# DEATH EVENT: 1
#
#
# anaemia: 1
# diabetes: 1
# sex: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# sex: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
# ejection fraction: 30
# high blood pressure: 1
# sex: 1
# smoking: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
#
#
# age: 67
#
#
# sex: 1
#
#
# anaemia: 1
# diabetes: 1
# ejection fraction: 30
# sex: 1
# smoking: 1
#
#
# creatinine phosphokinase: 582
# high blood pressure: 1
#
#
# age: 70
# creatinine phosphokinase: 618
#
#
# age: 70
# creatinine phosphokinase: 582
# diabetes: 1
# platelets: 25100
# sex: 1
#
#
# anaemia: 1
# creatinine phosphokinase: 1051
# diabetes: 1
# ejection fraction: 30
#
#
# diabetes: 1
#
#
# age: 70
# creatinine phosphokinase: 2695
# diabetes: 1
# sex: 1
#
#
# age: 70
# creatinine phosphokinase: 582
# platelets: 51000
# serum creatinine: 2.7
# sex: 1
# smoking: 1
#
#
# ejection fraction: 30
# serum creatinine: 3.8
# sex: 1
# smoking: 1
#
#
# age: 65
# creatinine phosphokinase: 1688
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# sex: 1
#
#
# anaemia: 1
# diabetes: 1
# sex: 1
#
#
# sex: 1
#
#
# creatinine phosphokinase: 582
# diabetes: 1
#
#
# age: 65
# creatinine phosphokinase: 892
# diabetes: 1
#
#
# age: 90
# anaemia: 1
#
#
# creatinine phosphokinase: 615
# diabetes: 1
#
#
# sex: 1
#
#
# diabetes: 1
# sex: 1
# smoking: 1
#
#
# anaemia: 1
# diabetes: 1
# sex: 1
# smoking: 1
#
#
# diabetes: 1
# high blood pressure: 1
# sex: 1
# smoking: 1
#
#
# creatinine phosphokinase: 1820
#
#
# creatinine phosphokinase: 2060
# diabetes: 1
# platelets: 742000
#
#
# creatinine phosphokinase: 2413
# sex: 1
# smoking: 1
#
#
# sex: 1
# smoking: 1
#
#
# age: 115
# anaemia: 129
# creatinine phosphokinase: 118
# diabetes: 125
# ejection fraction: 93
# high blood pressure: 105
# platelets: 11
# serum creatinine: 52
# serum sodium: 2
# male: 194
# female: 105
# smoking: 96
# Deaths: 96
# Items: age ane
# Items: age cre
# Items: age dia
# Items: age eje
# Items: age hig
# Items: age seC
# Items: age mal
# Items: age fem
# Items: age smo
# Items: age dth
# Items: ane cre
# Items: ane dia
# Items: ane eje
# Items: ane hig
# Items: ane seC
# Items: ane mal
# Items: ane fem
# Items: ane smo
# Items: ane dth
# Items: cre dia
# Items: cre eje
# Items: cre hig
# Items: cre seC
# Items: cre mal
# Items: cre fem
# Items: cre smo
# Items: cre dth
# Items: dia eje
# Items: dia hig
# Items: dia seC
# Items: dia mal
# Items: dia fem
# Items: dia smo
# Items: dia dth
# Items: eje hig
# Items: eje seC
# Items: eje mal
# Items: eje fem
# Items: eje smo
# Items: eje dth
# Items: hig seC
# Items: hig mal
# Items: hig fem
# Items: hig smo
# Items: hig dth
# Items: seC mal
# Items: seC fem
# Items: seC smo
# Items: seC dth
# Items: mal fem
# Items: mal smo
# Items: mal dth
# Items: fem smo
# Items: fem dth
# Items: smo dth
# Creating matches:
# {'age, ane': 0, 'age, cre': 0, 'age, dia': 0, 'age, eje': 0, 'age, hig': 0, 'age, seC': 0, 'age, mal': 0, 'age, fem': 0, 'age, smo': 0, 'age, dth': 0, 'ane, cre': 0, 'ane, dia': 0, 'ane, eje': 0, 'ane, hig': 0, 'ane, seC': 0, 'ane, mal': 0, 'ane, fem': 0, 'ane, smo': 0, 'ane, dth': 0, 'cre, dia': 0, 'cre, eje': 0, 'cre, hig': 0, 'cre, seC': 0, 'cre, mal': 0, 'cre, fem': 0, 'cre, smo': 0, '
0, 'ane, eje, mal, smo': 0, 'ane, hig, mal, smo': 0, 'ane, hig, mal, dth': 0, 'ane, mal, smo, dth': 0, 'cre, dia, mal, fem': 0, 'cre, dia, mal, smo': 0, 'cre, dia, mal, dth': 0, 'cre, eje, mal, smo': 0, 'cre, eje, mal, dth': 0, 'cre, mal, smo, dth': 0, 'dia, mal, smo, dth': 0, 'eje, mal, smo, dth': 0, 'hig, mal, smo, dth': 0}
#
#
# checking total matches:
# {}
#
#
# Creating matches:
# {}
#
#
# All Matches:
# {'age': 115, 'ane': 129, 'cre': 118, 'dia': 125, 'eje': 93, 'hig': 105, 'seC': 52, 'mal': 194, 'fem': 105, 'smo': 96, 'dth': 96, 'age, ane': 49, 'age, cre': 41, 'age, dia': 41, 'age, eje': 34, 'age, hig': 48, 'age, seC': 27, 'age, mal': 75, 'age, fem': 40, 'age, smo': 38, 'age, dth': 50, 'ane, cre': 32, 'ane, dia': 53, 'ane, eje': 43, 'ane, hig': 48, 'ane, mal': 77, 'ane, fem': 52, 'ane, smo': 34, 'ane, dth': 46, 'cre, dia': 53, 'cre, eje': 35, 'cre, hig': 37, 'cre, mal': 79, 'cre, fem': 39, 'cre, smo': 34, 'cre, dth': 37, 'dia, eje': 38, 'dia, hig': 43, 'dia, mal': 70, 'dia, fem': 55, 'dia, smo': 30, 'dia, dth': 40, 'eje, hig': 34, 'eje, mal': 65, 'eje, fem': 28, 'eje, smo': 32, 'eje, dth': 51, 'hig, mal': 61, 'hig, fem': 44, 'hig, smo': 30, 'hig, dth': 39, 'seC, mal': 36, 'seC, dth': 36, 'mal, smo': 92, 'mal, dth': 62, 'fem, dth': 34, 'smo, dth': 30, 'age, ane, hig': 25, 'age, ane, mal': 30, 'age, cre, mal': 29, 'age, dia, mal': 25, 'age, hig, mal': 29, 'age, mal, smo': 36, 'age, mal, dth': 36, 'ane, dia, mal': 25, 'ane, dia, fem': 28, 'ane, eje, mal': 26, 'ane, eje, dth': 25, 'ane, hig, mal': 25, 'ane, mal, smo': 32, 'ane, mal, dth': 26, 'cre, dia, mal': 28, 'cre, dia, fem': 25, 'cre, eje, mal': 28, 'cre, mal, smo': 34, 'cre, mal, dth': 27, 'dia, mal, smo': 28, 'eje, mal, smo': 30, 'eje, mal, dth': 35, 'hig, mal, smo': 27, 'mal, smo, dth': 27}
# Confidence that given other variables, death will occur:
# Given age, probabilty of death is: 0.43478260869565216
# Given ane, probabilty of death is: 0.35658914728682173
# Given cre, probabilty of death is: 0.3135593220338983
# Given dia, probabilty of death is: 0.32
# Given eje, probabilty of death is: 0.5483870967741935
# Given hig, probabilty of death is: 0.37142857142857144
# Given seC, probabilty of death is: 0.6923076923076923
# Given mal, probabilty of death is: 0.31958762886597936
# Given fem, probabilty of death is: 0.3238095238095238
# Given smo, probabilty of death is: 0.3125
# Given age, mal, probabilty of death is: 0.48
# Given ane, eje, probabilty of death is: 0.5813953488372093
# Given ane, mal, probabilty of death is: 0.33766233766233766
# Given cre, mal, probabilty of death is: 0.34177215189873417
# Given eje, mal, probabilty of death is: 0.5384615384615384
# Given mal, smo, probabilty of death is: 0.29347826086956524
