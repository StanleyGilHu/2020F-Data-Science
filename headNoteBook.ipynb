# %%
import pandas as pd
import math

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("HeartFailureData/heart_failure_clinical_records_dataset.csv")
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# #plt.plot(data.age)
# #plt.show()
# plt.hist(data.ejection_fraction)
# plt.show()

# %%
maleDie = data[(data.sex == 1) & (data.DEATH_EVENT == 1)]
maleLive = data[(data.sex == 1) & (data.DEATH_EVENT == 0)]
femaleDie = data[(data.sex == 0) & (data.DEATH_EVENT == 1)]
femaleLive = data[(data.sex == 0) & (data.DEATH_EVENT == 0)]
mdl = len(maleDie.index)
mll = len(maleLive.index)
fdl = len(femaleDie.index)
fll = len(femaleLive.index)
total = mdl + mll + fdl + fll
percent = [mdl/ total, mll/ total, fdl/ total, fll/total]
labels = ["Male Deaths", "Male Survive", "Female Die", "Female Survive"]
plt.pie(percent, labels = labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# data.describe()

# %% [markdown]
# breaks = jenkspy.jenks_breaks(data["age"], nb_class = 3)
# print(breaks)
# #data["jenks"] = pd.cut(data["age"], bins = breaks, labels = ["bucket1", "bucket2"])
# #data
# pbreaks = jenkspy.jenks_breaks(data["platelets"], nb_class = 6)
# print(pbreaks)

# %%
pDeath = len(data[data.DEATH_EVENT == 1]) / 299
pLive = len(data[data.DEATH_EVENT == 0]) / 299
info = (-(pDeath * math.log(pDeath, 2))) - (pLive * math.log(pLive, 2))
info
# Out:
# 0.9055415027672631

# %%
pLowEjectDeath = len(data[(data.ejection_fraction < 50) & (data.DEATH_EVENT == 1)]) / 299
pLowEjectLive = len(data[(data.ejection_fraction < 50) & (data.DEATH_EVENT == 0)]) / 299
pNormalEjectDeath = len(data[(data.ejection_fraction >= 50) & (data.ejection_fraction <= 70) & (data.DEATH_EVENT == 1)]) / 299
pNormalEjectLive = len(data[(data.ejection_fraction >= 50) & (data.ejection_fraction <= 70) & (data.DEATH_EVENT == 1)]) / 299
pHighEjectDeath = len(data[(data.ejection_fraction > 70) & (data.DEATH_EVENT == 1)])
pHighEjectLive = len(data[(data.ejection_fraction > 70) & (data.DEATH_EVENT == 0)]) 
pHighEjectDeath
# Out:
# 299
